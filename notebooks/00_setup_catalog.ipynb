# %% [markdown]
# # Setup — catálogo e schemas
# Roda uma vez só, antes da primeira ingestão. As tabelas da pipeline (`sample_mflix__<coleção>`, `control_ingestion_log` etc.) se criam sozinhas na primeira execução — não precisa criar nada manual.

# %%
# %sql
CREATE CATALOG IF NOT EXISTS meu_catalog

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS meu_catalog.landing;
CREATE SCHEMA IF NOT EXISTS meu_catalog.bronze;

# %% [markdown]
# ## Antes de rodar a pipeline
# Roda o `create-secret.ipynb` primeiro pra criar o secret do Mongo. Ele fica separado do resto do código de propósito.
